# %%
import sympy as sp

# %% [markdown]
# # 16.7.4

# %%
x, y, z = sp.symbols("x y z")
z = (1 - x * y) / (x + y)
z
# Out:
# (-x*y + 1)/(x + y)

# %%
sp.simplify(sp.diff(z, x))
# Out:
# (x*y - y*(x + y) - 1)/(x + y)**2

# %%
sp.simplify(sp.diff(z, y))
# Out:
# (x*y - x*(x + y) - 1)/(x + y)**2

# %%
sp.simplify(sp.diff(z, x, x))
# Out:
# 2*y**2/(x + y)**3 + 2/(x + y)**3

# %%
sp.simplify(sp.diff(z, x, y))
# Out:
# 2*(-x*y + 1)/(x + y)**3

# %%
sp.simplify(sp.diff(z, y, y))
# Out:
# 2*x**2/(x + y)**3 + 2/(x + y)**3

# %% [markdown]
# # 16.7.5

# %%
x, y, z = sp.symbols("x y z")
sp.solveset(x / y + y / z + z / x - 1, x)
# Out:
# Complement(FiniteSet(-y*(y - z)/(2*z) - sqrt(y*(y**3 - 2*y**2*z + y*z**2 - 4*z**3))/(2*z), -y*(y - z)/(2*z) + sqrt(y*(y**3 - 2*y**2*z + y*z**2 - 4*z**3))/(2*z)), FiniteSet(0))

# %%
F = x / y + y / z + z / x - 1
F
# Out:
# x/y + y/z - 1 + z/x

# %%
z_x = -sp.diff(F,x) / sp.diff(F,z)
sp.simplify(z_x)
# Out:
# z**2*(x**2 - y*z)/(x*y*(x*y - z**2))

# %%
z_y = -sp.diff(F,y) / sp.diff(F,z)
sp.simplify(z_y)
# Out:
# x*z*(-x*z + y**2)/(y**2*(x*y - z**2))

# %%
z_xx = sp.diff(z_x,x)
sp.simplify(z_xx)
# Out:
# z**3*(2*y*(x*y - z**2) - z*(x**2 - y*z))/(x**2*y*(x*y - z**2)**2)

# %%
z_xy = sp.diff(z_x,y)
sp.simplify(z_xy)
# Out:
# -z**2*(x*(x*y - z**2) + y*(x**2 - y*z))/(y**2*(x*y - z**2)**2)

# %%
z_yx = sp.diff(z_y,x)
sp.simplify(z_yx)
# Out:
# z**2*(-x*(x*y - z**2) + z*(x*z - y**2))/(y**2*(x*y - z**2)**2)

# %%
z_yx == z_xy
# Out:
# False

# %%
z_yy = sp.diff(z_y,y)
sp.simplify(z_yy)
# Out:
# x**2*z*(y*(x*z - y**2) + 2*z*(x*y - z**2))/(y**3*(x*y - z**2)**2)

# %% [markdown]
# # 16.7.11 (1)

# %%
f = sp.Function("f")
z = f(x + y, z + y)

# %%
sp.simplify(sp.diff(z, x))
# Out:
# Subs(Derivative(f(_xi_1, y + z), _xi_1), _xi_1, x + y)

# %%
sp.simplify(sp.diff(z, x, y))
# Out:
# Subs(Derivative(f(_xi_1, y + z), (_xi_1, 2)), _xi_1, x + y) + Subs(Derivative(f(_xi_1, _xi_2), _xi_1, _xi_2), (_xi_2, _xi_1), (y + z, x + y))

# %% [markdown]
# # 16.7.11 (2)

# %%
f = sp.Function("f")
F = f(x + y, y + z, z + x)

# %%
z_x = -sp.diff(F, x) / sp.diff(F, z)
sp.simplify(z_x)
# Out:
# -((Subs(Derivative(f(_xi_1, y + z), _xi_1), _xi_1, x + y) + 1)*Subs(Derivative(f(x + y, y + f(x + y, y + z), _xi_3), _xi_3), _xi_3, x + f(x + y, y + z)) + Subs(Derivative(f(_xi_1, y + z), _xi_1), _xi_1, x + y)*Subs(Derivative(f(x + y, _xi_2, x + f(x + y, y + z)), _xi_2), _xi_2, y + f(x + y, y + z)) + Subs(Derivative(f(_xi_1, y + f(x + y, y + z), x + f(x + y, y + z)), _xi_1), _xi_1, x + y))/(Subs(Derivative(f(x + y, _xi_2, x + f(x + y, y + z)), _xi_2), _xi_2, y + f(x + y, y + z)) + Subs(Derivative(f(x + y, y + f(x + y, y + z), _xi_3), _xi_3), _xi_3, x + f(x + y, y + z)))

# %% [markdown]
# # 17.2.1

# %%
f = sp.Matrix([x**2 - 2 * y, x**2 - 2 * x * y, 3 * x**2 * y - 2 * y])
f
# Out:
# Matrix([
# [    x**2 - 2*y],
# [  x**2 - 2*x*y],
# [3*x**2*y - 2*y]])

# %%
X = sp.Matrix([x, y])
sp.simplify(f.jacobian(X))
# Out:
# Matrix([
# [      2*x,         -2],
# [2*x - 2*y,       -2*x],
# [    6*x*y, 3*x**2 - 2]])

# %%
f = sp.Matrix([sp.log(x**2 + y**2), sp.atan2(y, x)])
f
# Out:
# Matrix([
# [log(x**2 + y**2)],
# [     atan2(y, x)]])

# %%
sp.simplify(f.jacobian(X))
# Out:
# Matrix([
# [2*x/(x**2 + y**2), 2*y/(x**2 + y**2)],
# [ -y/(x**2 + y**2),   x/(x**2 + y**2)]])

# %%
i, j = sp.symbols("i j")
f = sp.Matrix([sp.exp(x + 2 * y) * i + sp.sin(y + 2 * x) * j])
f
# Out:
# Matrix([[i*exp(x + 2*y) + j*sin(2*x + y)]])

# %%
sp.simplify(f.jacobian(X))
# Out:
# Matrix([[i*exp(x + 2*y) + 2*j*cos(2*x + y), 2*i*exp(x + 2*y) + j*cos(2*x + y)]])

# %% [markdown]
# # 17.2.11

# %%
f1_f, f2_f, f3_f = sp.Function("f1"), sp.Function("f2"), sp.Function("f3")
g1_f, g2_f, g3_f = sp.Function("g1"), sp.Function("g2"), sp.Function("g3")
t = sp.symbols("t")
f1, f2, f3 = f1_f(t), f2_f(t), f3_f(t)
g1, g2, g3 = g1_f(t), g2_f(t), g3_f(t)

# %%
f = sp.Matrix([f1, f2, f3])
g = sp.Matrix([g1, g2, g3])

# %%
LHS = f.cross(g).diff(t)
sp.simplify(LHS)
# Out:
# Matrix([
# [ f2(t)*Derivative(g3(t), t) - f3(t)*Derivative(g2(t), t) - g2(t)*Derivative(f3(t), t) + g3(t)*Derivative(f2(t), t)],
# [-f1(t)*Derivative(g3(t), t) + f3(t)*Derivative(g1(t), t) + g1(t)*Derivative(f3(t), t) - g3(t)*Derivative(f1(t), t)],
# [ f1(t)*Derivative(g2(t), t) - f2(t)*Derivative(g1(t), t) - g1(t)*Derivative(f2(t), t) + g2(t)*Derivative(f1(t), t)]])

# %%
RHS = f.diff(t).cross(g) + f.cross(g.diff(t))
sp.simplify(RHS)
# Out:
# Matrix([
# [ f2(t)*Derivative(g3(t), t) - f3(t)*Derivative(g2(t), t) - g2(t)*Derivative(f3(t), t) + g3(t)*Derivative(f2(t), t)],
# [-f1(t)*Derivative(g3(t), t) + f3(t)*Derivative(g1(t), t) + g1(t)*Derivative(f3(t), t) - g3(t)*Derivative(f1(t), t)],
# [ f1(t)*Derivative(g2(t), t) - f2(t)*Derivative(g1(t), t) - g1(t)*Derivative(f2(t), t) + g2(t)*Derivative(f1(t), t)]])

# %%
LHS == RHS
# Out:
# True
